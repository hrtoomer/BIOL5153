# %% [markdown]
# ### parseGFF.py Excercise (Updated April 8, 2018)

# %%
# specify input files
gff='watermelon.gff'
fasta_file= 'watermelon.fsa'

#open the FASTA file
fasta=open(fasta_file,'r')

# %%
# solution 4
file_in_list = []
with open(fasta_file) as fasta:
    file_in_list = fasta.read().splitlines()
    file_in_list = fasta.splitlines()
    
    genome = file_in_list[1]
    
print(genome)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-0e79cc224060> in <module>()
#       3 with open(fasta_file) as fasta:
#       4     file_in_list = fasta.read().splitlines()
# ----> 5     file_in_list = fasta.splitlines()
#       6
#       7     genome = file_in_list[1]
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'splitlines'

# %%
#solution 1
sequence=next(fasta_file)
sequence=fasta_file.read()
sequence=sequence.rstrip('/n')
print(len(sequence))

# solution 2
line_counter =1
for line in fasta_file:
    if line_counter == 2:
        sequence = line.rstrip('\n')
    line_counter += 1

# solution 3
fasta_contents= fasta.read()
header = fasta_contents.split('\n')[0]
sequence = fasta_contents.split('\n')[1]
fasta.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-cc0443cec245> in <module>()
#       1
#       2 #solution 1
# ----> 3 sequence=next(fasta_file)
#       4 sequence=fasta_file.read()
#       5 sequence=sequence.rstrip('/n')
#
# TypeError: 'str' object is not an iterator

# %%
# the variable 'genome' holds the genome sequence
# genome =

# open the GFF file
gff=open(gff_file,'r')


# read the GFF file, line by line 
gff = open(gff, 'r')
for line in gff:
    #skip blank lines
    
    
    # remove line breaks
    line = line.rstrip('\n')
    print(line)
    
    # split each line on the tab character
    # sequence, source, feature, begin, end, length, strand, phase, attributes = line.split('\t')

    fields= line.split('\t')
    print(fields[3],fields[4])
    
    # extract the DNA sequences from the genome for this feature
    substring = 

    
    #print the DNA sequence for this feaure
    
    
    # calculuate the GC content for this feature, and print it to the screen
    
gff.close()
# Out:
#   File "<ipython-input-11-c5a3f7d55a4c>", line 25
#     substring =
#                 ^
# SyntaxError: invalid syntax

# %%
name = "watermelon.fsa"
s = ""
ID = ""
with open(name,'r') as cDNAs:
    for line in cDNAs:
        if line.startswith('>'): #If it's a header:
            if(ID != ""): #If there is a sequence.
                print (ID + "\n" + s + 2 * "\n")
                cDNA(ID,s)
            ID = line[1: line.find(' ')]
            s = "" #Initializes the sequence.
        else:
            s += line #The sequence itself.
            s = s.replace("\n", "") #Removes all the end of lines.

    print(ID + "\n" + s + 2 * "\n")
    cDNA(ID,s)
# Out:
# watermelon
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-eaeefa949c70> in <module>()
#      15
#      16     print(ID + "\n" + s + 2 * "\n")
# ---> 17     cDNA(ID,s)
#
# NameError: name 'cDNA' is not defined
